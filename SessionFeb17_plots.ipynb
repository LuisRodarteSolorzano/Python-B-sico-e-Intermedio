# %% [markdown]
# Based on https://f0nzie.github.io/rmarkdown-python-plotnine/

# %%
from plotnine import *
from plotnine.data import *

# %%
type(mpg)
# Out:
# pandas.core.frame.DataFrame

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
ggplot(data=mpg, mapping=aes("displ","hwy")) +\
    geom_point()
# Out:
# <ggplot: (8757181127798)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point() +\
geom_point(data=mpg.query("displ > 5 & hwy > 20"), colour="red", size=2.2)
# Out:
# <ggplot: (8757181094768)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy", color="class"))
# Out:
# <ggplot: (8757281727964)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy"), color="blue")
# Out:
# <ggplot: (8757180937813)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy")) +\
facet_wrap("class", nrow=2)
# Out:
# <ggplot: (8757180917520)>

# %%
# ?geom_smooth

# %%
ggplot(data=mpg,mapping=aes(x="displ", y="hwy")) +\
geom_point() +\
geom_smooth()
# Out:
# /usr/local/lib/python3.8/dist-packages/plotnine/stats/smoothers.py:310: PlotnineWarning: Confidence intervals are not yet implementedfor lowess smoothings.
# <ggplot: (8757178141636)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy"), position="jitter")
# Out:
# <ggplot: (8757178065481)>

# %%
ggplot(data=mpg) +\
geom_density(mapping=aes(x="hwy"),adjust=0.9)+geom_rug(aes(x="hwy"))+geom_density(mapping=aes(x="hwy"),adjust=0.1)
# Out:
# <ggplot: (8757178001677)>
